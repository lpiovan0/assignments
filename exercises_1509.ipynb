# %%
def main():
    #1 Defining a variable for the membranePotential:
    membranePotential = float(-75)
    #2: The membrane potential is a floating point number because we need decimal fractions
    #3: I initialized it as -75
    #4: I'm increasing the membrane potential by 20
    membranePotential += 20
    #5: Printing the value:
    print(membranePotential)

if __name__ == "__main__":
    main()
# Out:
# -55.0

# %%
#1 This time I'm not declaring the type of membranePotential
#2 Initializing as 1
membranePotential = 1
#3 The table view of the variable tab in the debug panel shows that membranePotential's datatype is int
membranePotential *= 0.7
#4 Now the shown datatype is float. This happened because the variable had to be converted into float in order to be multiplied with another float
#5 I'm defining a new variable to initialize it with 1.0. Debug mode shows it as float.
membranePotential1 = 1.0

# %%
#Exercise 3
#Code from neuron1.py:
membranePotential = float(input())
if membranePotential >= float(-65):
    print(5)
else:
    print(0)

# %%
#Code from neuron2.py:
spike = float(input())
membranePotential = float(-65) + spike
print(membranePotential)
#I initialized this new membrane potential at -65 and added the input to it

# %% [markdown]
# ![Screenshot 2023-09-15 at 16.47.09.png](attachment:2f0c4cad-ff68-493a-96e0-d189fc76bffb.png)
# If I input a membrane potential of -66, it doesn't reach -65 so the first file outputs 0; the second output therefore stays -65. With -64 as the first output, the first output is 5, which taken as the input of the second file gives -60.
